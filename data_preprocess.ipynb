# %%
import pandas as pd

# %%
iris=pd.read_csv('/content/sample_data/iris.csv')
df=pd.read_csv('/content/covid_19_india.csv',parse_dates=['Date'],dayfirst=True)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris[iris['sepal_width']>4]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa

# %%
iris[iris['petal_width']>1]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [93 rows x 5 columns]

# %%
iris[iris['petal_width']>2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data= iris,hue='class')
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
y=iris[['sepal_length']]
x=iris[['sepal_width']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.head()
# Out:
#     sepal_width
# 62          2.2
# 54          2.8
# 58          2.9
# 21          3.7
# 20          3.4

# %%
x_test.head()
# Out:
#      sepal_width
# 84           3.0
# 143          3.2
# 129          3.0
# 104          3.0
# 69           2.5

# %%
y_train.head()
# Out:
#     sepal_length
# 62           6.0
# 54           6.5
# 58           6.6
# 21           5.1
# 20           5.4

# %%
y_test.head()
# Out:
#      sepal_length
# 84            5.4
# 143           6.8
# 129           7.2
# 104           6.5
# 69            5.6

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      sepal_length
# 84            5.4
# 143           6.8
# 129           7.2
# 104           6.5
# 69            5.6

# %%
y_pred[0:5]
# Out:
# array([[5.88407345],
#        [5.82241671],
#        [5.88407345],
#        [5.88407345],
#        [6.0382153 ]])

# %%
 from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.8528390113523189

# %%
y=iris[['sepal_length','petal_length','petal_width']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
lr2=LinearRegression()
lr2.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred2=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred2)
# Out:
# 1.2278617559164038

# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
df.head()
# Out:
#    Sno       Date     Time  ... Cured Deaths Confirmed
# 0    1 2020-01-30  6:00 PM  ...     0      0         1
# 1    2 2020-01-31  6:00 PM  ...     0      0         1
# 2    3 2020-02-01  6:00 PM  ...     0      0         2
# 3    4 2020-02-02  6:00 PM  ...     0      0         3
# 4    5 2020-02-03  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
df=df[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]
df.columns=['date','state','cured','deaths','confirmed']

# %%
df.head()
# Out:
#         date   state  cured  deaths  confirmed
# 0 2020-01-30  Kerala      0       0          1
# 1 2020-01-31  Kerala      0       0          1
# 2 2020-02-01  Kerala      0       0          2
# 3 2020-02-02  Kerala      0       0          3
# 4 2020-02-03  Kerala      0       0          3

# %%
 today=df[df.date=='2020-07-17']

# %%
today.head()
# Out:
#            date                        state  cured  deaths  confirmed
# 4179 2020-07-17  Andaman and Nicobar Islands    133       0        180
# 4180 2020-07-17               Andhra Pradesh  19393     492      38044
# 4181 2020-07-17            Arunachal Pradesh    153       3        543
# 4182 2020-07-17                        Assam  12888      48      19754
# 4183 2020-07-17                        Bihar  14018     197      21764

# %%
sorted=today.sort_values(by="confirmed",ascending=False)

# %%
sorted
# Out:
#            date                                     state  ...  deaths  confirmed
# 4198 2020-07-17                               Maharashtra  ...   11194     284281
# 4208 2020-07-17                                Tamil Nadu  ...    2236     156369
# 4187 2020-07-17                                     Delhi  ...    3545     118645
# 4194 2020-07-17                                 Karnataka  ...    1032      51422
# 4189 2020-07-17                                   Gujarat  ...    2089      45481
# 4212 2020-07-17                             Uttar Pradesh  ...    1046      43441
# 4209 2020-07-17                                 Telengana  ...     396      41018
# 4180 2020-07-17                            Andhra Pradesh  ...     492      38044
# 4213 2020-07-17                               West Bengal  ...    1023      36117
# 4206 2020-07-17                                 Rajasthan  ...     538      27174
# 4190 2020-07-17                                   Haryana  ...     322      24002
# 4183 2020-07-17                                     Bihar  ...     197      21764
# 4197 2020-07-17                            Madhya Pradesh  ...     689      20378
# 4182 2020-07-17                                     Assam  ...      48      19754
# 4203 2020-07-17                                    Odisha  ...      79      15392
# 4192 2020-07-17                         Jammu and Kashmir  ...     222      12156
# 4195 2020-07-17                                    Kerala  ...      37      10275
# 4205 2020-07-17                                    Punjab  ...     230       9094
# 4185 2020-07-17                              Chhattisgarh  ...      21       4732
# 4193 2020-07-17                                 Jharkhand  ...      42       4624
# 4211 2020-07-17                               Uttarakhand  ...      50       3982
# 4188 2020-07-17                                       Goa  ...      19       3108
# 4210 2020-07-17                                   Tripura  ...       3       2283
# 4199 2020-07-17                                   Manipur  ...       0       1764
# 4204 2020-07-17                                Puducherry  ...      22       1743
# 4191 2020-07-17                          Himachal Pradesh  ...      11       1377
# 4196 2020-07-17                                    Ladakh  ...       1       1147
# 4202 2020-07-17                                  Nagaland  ...       0        916
# 4184 2020-07-17                                Chandigarh  ...      11        651
# 4186 2020-07-17  Dadra and Nagar Haveli and Daman and Diu  ...       2        552
# 4181 2020-07-17                         Arunachal Pradesh  ...       3        543
# 4214 2020-07-17          Cases being reassigned to states  ...       0        531
# 4200 2020-07-17                                 Meghalaya  ...       2        377
# 4201 2020-07-17                                   Mizoram  ...       0        272
# 4207 2020-07-17                                    Sikkim  ...       0        243
# 4179 2020-07-17               Andaman and Nicobar Islands  ...       0        180
#
# [36 rows x 5 columns]
